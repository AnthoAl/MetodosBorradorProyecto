# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Importación y carga del modelo entrenado

# %%
# %autoreload 2
from Blackbox import load_model
model = load_model()
model
# Out:
# Current working directory: c:\antho_EPN\Fourth Semester\MATERIA METODOS\Proyecto I BIM\Proyecto
# <Sequential name=sequential_14, built=True>

# %% [markdown]
# Ejemplos proporcionados inicialmente para identificar la ubicación de las fronteras de decisión

# %%
# %autoreload 2
from Blackbox import predict_point, predict_batch
predict_batch(model, [0.2, 1.1], [0.4, 1.3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# [1.0, 0.0]

# %% [markdown]
# Muestreo de datos para visualizar la región donde el modelo da como resultado 1

# %%
import numpy as np
x1_values = np.linspace(0, 1.5, 30)
x2_values = np.linspace(-1, 1.5, 30)

uno_points = []
cero_points = []

for x1 in x1_values:
    for x2 in x2_values:
        y = predict_point(model, x1, x2)
        print(f"x1: {x1}, x2: {x2} => y: {y}")
        if y == 1:
            uno_points.append((x1, x2))
        else:
            cero_points.append((x1, x2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# x1: 0.0, x2: -1.0 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# x1: 0.0, x2: -0.9137931034482758 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# x1: 0.0, x2: -0.8275862068965517 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# x1: 0.0, x2: -0.7413793103448276 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# x1: 0.0, x2: -0.6551724137931034 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# x1: 0.0, x2: -0.5689655172413792 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# x1: 0.0, x2: -0.48275862068965514 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# x1: 0.0, x2: -0.39655172413793105 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# x1: 0.0, x2: -0.31034482758620685 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# x1: 0.0, x2: -0.22413793103448265 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# x1: 0.0, x2: -0.13793103448275856 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ...

# %%
import numpy as np
x1_values = np.linspace(1.5, 5, 30)
x2_values = np.linspace(-1, 0.5, 30)

for x1 in x1_values:
    for x2 in x2_values:
        y = predict_point(model, x1, x2)
        print(f"x1: {x1}, x2: {x2} => y: {y}")
        if y == 1:
            uno_points.append((x1, x2))
        else:
            continue
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# x1: 1.5, x2: -1.0 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# x1: 1.5, x2: -0.9482758620689655 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# x1: 1.5, x2: -0.896551724137931 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# x1: 1.5, x2: -0.8448275862068966 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# x1: 1.5, x2: -0.7931034482758621 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# x1: 1.5, x2: -0.7413793103448276 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# x1: 1.5, x2: -0.6896551724137931 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# x1: 1.5, x2: -0.6379310344827587 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# x1: 1.5, x2: -0.5862068965517242 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# x1: 1.5, x2: -0.5344827586206897 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# x1: 1.5, x2: -0.48275862068965514 => y: 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ...

# %% [markdown]
# Graficación del muestreo de las salidas del modelo

# %%
import matplotlib.pyplot as plt

# Se separa las coordenadas x1 y x2 para los puntos con salida 1
if 'uno_points' in locals() and uno_points:
    x1_uno = [p[0] for p in uno_points]
    x2_uno = [p[1] for p in uno_points]
else:
    x1_uno, x2_uno = [], []


plt.figure(figsize=(8, 6))
plt.scatter(x1_uno, x2_uno, color='blue', marker='o', label='Salida = 1.0', s=5) 
plt.title('Muestreo de Salidas del Modelo')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

plt.xlim(-0.1,5.1)
plt.ylim(-0.5,1.5)
plt.show()

# %% [markdown]
# Códigos para realizar el muestreo de los puntos ubicados en las fronteras de decisión del modelo a través del método de bisección

# %%
import numpy as np

x1_values = np.linspace(0.00, 1.5, 50)
x2_values = np.linspace(-1, 1.5, 20)
tolerancia = 0.00001
frontera_superior = []
frontera_inferior = []

for x1 in x1_values:
    
    for x2 in x2_values:
        y = predict_point(model, x1, x2)
        if y == 1:
            x2_lim_bajo_sup = x2
            break
    
    # Frontera superior - Cambio de 1 a 0
    x2_lim_alto_sup = 1.5

    if predict_point(model, x1, x2_lim_alto_sup) == 0.0:
        lim_bajo_sup, lim_alto_sup = x2_lim_bajo_sup, x2_lim_alto_sup
        while abs(lim_alto_sup - lim_bajo_sup) > tolerancia:
            x2_medio = (lim_bajo_sup + lim_alto_sup) / 2
            if predict_point(model, x1, x2_medio) == 1.0:
                lim_bajo_sup = x2_medio
            else:
                lim_alto_sup = x2_medio
        frontera_superior.append((x1, (lim_bajo_sup + lim_alto_sup) / 2))
    
    # Frontera inferior - Cambio de 0 a 1
    x2_lim_alto_inf = x2 
    x2_lim_bajo_inf = -1.5
    
    if predict_point(model, x1, x2_lim_bajo_inf) == 0.0:
        lim_bajo_inf, lim_alto_inf = x2_lim_bajo_inf, x2_lim_alto_inf
        while abs(lim_alto_inf - lim_bajo_inf) > tolerancia:
            x2_medio = (lim_bajo_inf + lim_alto_inf) / 2
            if predict_point(model, x1, x2_medio) == 0.0:
                lim_bajo_inf = x2_medio
            else:
                lim_alto_inf = x2_medio
        frontera_inferior.append((x1, (lim_bajo_inf + lim_alto_inf) / 2))

print(f"Puntos Frontera Superior: {len(frontera_superior)}")
print(f"Puntos Frontera Inferior: {len(frontera_inferior)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ...

# %%
import numpy as np

x1_values = np.linspace(1.5, 5, 50)
x2_values = np.linspace(-0.5, 0.5, 20)
tolerancia = 0.00001

for x1 in x1_values:
    
    for x2 in x2_values:
        y = predict_point(model, x1, x2)
        if y == 1:
            x2_lim_bajo_sup = x2
            break
    
    # Frontera superior - Cambio de 1 a 0
    x2_lim_alto_sup = 1.5

    if predict_point(model, x1, x2_lim_alto_sup) == 0.0:
        lim_bajo_sup, lim_alto_sup = x2_lim_bajo_sup, x2_lim_alto_sup
        while abs(lim_alto_sup - lim_bajo_sup) > tolerancia:
            x2_medio = (lim_bajo_sup + lim_alto_sup) / 2
            if predict_point(model, x1, x2_medio) == 1.0:
                lim_bajo_sup = x2_medio
            else:
                lim_alto_sup = x2_medio
        frontera_superior.append((x1, (lim_bajo_sup + lim_alto_sup) / 2))
    
    # Frontera inferior - Cambio de 0 a 1
    x2_lim_alto_inf = x2 
    x2_lim_bajo_inf = -1.5
    
    if predict_point(model, x1, x2_lim_bajo_inf) == 0.0:
        lim_bajo_inf, lim_alto_inf = x2_lim_bajo_inf, x2_lim_alto_inf
        while abs(lim_alto_inf - lim_bajo_inf) > tolerancia:
            x2_medio = (lim_bajo_inf + lim_alto_inf) / 2
            if predict_point(model, x1, x2_medio) == 0.0:
                lim_bajo_inf = x2_medio
            else:
                lim_alto_inf = x2_medio
        frontera_inferior.append((x1, (lim_bajo_inf + lim_alto_inf) / 2))

print(f"Puntos Frontera Superior: {len(frontera_superior)}")
print(f"Puntos Frontera Inferior: {len(frontera_inferior)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ...

# %% [markdown]
# Graficación de las fronteras de decisión encontradas por el algoritmo de doble bisección

# %%
import matplotlib.pyplot as plt
import numpy as np

# Se extrae coordenadas para la Frontera Superior
if frontera_superior:
    x1_sup = [p[0] for p in frontera_superior]
    x2_sup = [p[1] for p in frontera_superior]
else:
    x1_sup, x2_sup = [], []
    print("Advertencia: La lista frontera_superior está vacía.")

# Se extrae coordenadas para la Frontera Inferior
if frontera_inferior:
    x1_inf = [p[0] for p in frontera_inferior]
    x2_inf = [p[1] for p in frontera_inferior]
else:
    x1_inf, x2_inf = [], []
    print("Advertencia: La lista frontera_inferior está vacía.")


plt.figure(figsize=(10, 7))

# Frontera Superior (donde 1 -> 0)
plt.plot(
    x1_sup, 
    x2_sup, 
    color='orange', 
    marker='o', 
    markersize=3, 
    linestyle='-', 
    label='Frontera Superior (1 → 0)'
)

# Frontera Inferior (donde 0 -> 1)
plt.plot(
    x1_inf, 
    x2_inf, 
    color='green', 
    marker='x', 
    markersize=3, 
    linestyle='-', 
    label='Frontera Inferior (0 → 1)'
)

plt.title('Fronteras de Decisión del Modelo')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

all_x2 = x2_sup + x2_inf
if all_x2:
    y_min = min(all_x2) - 0.1
    y_max = max(all_x2) + 0.1
    plt.ylim(y_min, y_max)
    
plt.xlim(0.0, 5) 

plt.show()

# %% [markdown]
# Algoritmo de ajuste de curvas para la frontera inferior utilizando el método de Levenberg-Marquardt

# %%
from scipy.optimize import curve_fit
import time

x1_inf_data = np.array([p[0] for p in frontera_inferior])
x2_inf_data = np.array([p[1] for p in frontera_inferior])
    
def modelo_regresion_nolineal(x, A, B, C, D):
    return A * np.sin(B * x + C) / (x + 0.1) + D

p0_inf_final = [0.7, 8.0, 0.0, 0.05] 

start_time = time.perf_counter()


popt_inf, pcov_inf = curve_fit(
    modelo_regresion_nolineal, 
    x1_inf_data, 
    x2_inf_data, 
    p0=p0_inf_final, 
    maxfev=5000
)

end_time = time.perf_counter()

# Cálculo del tiempo total de ejecución
elapsed_time = end_time - start_time
A_inf, B_inf, C_inf, D_inf = popt_inf
x2_pred_at_zero = modelo_regresion_nolineal(0.01, *popt_inf) 

print(f"Tiempo Total de Ejecución: {elapsed_time:.6f} segundos")

print("\nParámetros obtenidos por Levenberg-Maequardt (A, B, C, D):")
print(popt_inf)

print("\n--- RESULTADOS ---")
print(f"Relación Analítica: x2 = {A_inf:.4f} * sin({B_inf:.4f} * x1 + {C_inf:.4f}) / (x1 + 0.1) + {D_inf:.4f}")
print(f"Ejemplo del valor predicho para x1=0.01: x2 ≈ {x2_pred_at_zero:.4f}")
# Out:
# Tiempo Total de Ejecución: 0.008841 segundos
#
# Parámetros obtenidos por Levenberg-Maequardt (A, B, C, D):
# [ 0.13543566  8.95118215  0.63047492 -0.05461683]
#
# --- RESULTADOS ---
# Relación Analítica: x2 = 0.1354 * sin(8.9512 * x1 + 0.6305) / (x1 + 0.1) + -0.0546
# Ejemplo del valor predicho para x1=0.01: x2 ≈ 0.7572

# %% [markdown]
# Algoritmo de ajuste de curvas para la frontera inferior utilizando el método de Gauss-Newton

# %%
import numpy as np
import time

def modelo_regresion_nolineal(x, A, B, C, D):
    return A * np.sin(B * x + C) / (x + 0.1) + D

# Función de Residuos (Error)
def residual(beta, x_data, y_data):
    A, B, C, D = beta
    return y_data - modelo_regresion_nolineal(x_data, A, B, C, D)

def jacobian(beta, x_data):
    A, B, C, D = beta
    
    den = x_data + 0.1
    sin_term = np.sin(B * x_data + C)
    cos_term = np.cos(B * x_data + C)
    
    J_A = sin_term / den
    
    J_B = A * x_data * cos_term / den
    
    J_C = A * cos_term / den
    
    J_D = np.ones_like(x_data)
    
    return np.vstack((J_A, J_B, J_C, J_D)).T

def gauss_newton(x_data, y_data, beta_initial, max_iter=100, tolerance=1e-6):
    
    beta = np.array(beta_initial)
    
    start_time = time.perf_counter()

    for i in range(max_iter):
        
        r = residual(beta, x_data, y_data)
        
        J = jacobian(beta, x_data)
        
        JTJ = J.T @ J
        JTr = J.T @ r
        
        try:
            delta_beta = np.linalg.lstsq(JTJ, JTr, rcond=None)[0]
        except np.linalg.LinAlgError:
            print("Advertencia: Matriz JTJ singular. Deteniendo el algoritmo.")
            break
            
        beta_new = beta + delta_beta
        
        error = np.linalg.norm(delta_beta)
        if error < tolerance:
            print(f"Convergencia lograda en {i+1} iteraciones.")
            break
            
        beta = beta_new
        
        if i == max_iter - 1:
            print("Advertencia: Máximo de iteraciones alcanzado.")
    
    end_time = time.perf_counter()
    elapsed_time = end_time - start_time
    
    return beta, elapsed_time


beta_initial = [0.6, 7.5, 0.1, 0.1] 

# Parámetros óptimos encontrados por Gauss-Newton
beta_opt_gn, time_gn = gauss_newton(x1_inf_data, x2_inf_data, beta_initial)

A_infg, B_infg, C_infg, D_infg = beta_opt_gn

print("\nParámetros obtenidos por Gauss-Newton (A, B, C, D):")
print(beta_opt_gn)
print(f"Tiempo Total de Ejecución: {time_gn:.6f} segundos")

x2_pred_at_zero = modelo_regresion_nolineal(0.01, *beta_opt_gn)

print("\n--- RESULTADOS ---")
print(f"Relación Analítica: x2 = {A_infg:.4f} * sin({B_infg:.4f} * x1 + {C_infg:.4f}) / (x1 + 0.1) + {D_infg:.4f}")
print(f"Ejemplo del valor predicho en x1=0.01: x2 ≈ {x2_pred_at_zero:.4f}")
# Out:
# Convergencia lograda en 70 iteraciones.
#
# Parámetros obtenidos por Gauss-Newton (A, B, C, D):
# [ 0.13543742  8.95141279  0.63044158 -0.05461769]
# Tiempo Total de Ejecución: 0.011296 segundos
#
# --- RESULTADOS ---
# Relación Analítica: x2 = 0.1354 * sin(8.9514 * x1 + 0.6304) / (x1 + 0.1) + -0.0546
# Ejemplo del valor predicho en x1=0.01: x2 ≈ 0.7572

# %% [markdown]
# Generación de la gráfica comparativa entre el modelo ajustado y la función original

# %%
import numpy as np
import matplotlib.pyplot as plt

def fun_original(x):
    return np.where(
        np.isclose(x, 0.0),
        1.0,
        np.sin(10 * x) / (10 * x)
    )

def fun_levenvergh(x):
    return A_inf * np.sin(B_inf * x + C_inf) / (x + 0.1) + D_inf

def fun_gauss(x):
    return A_infg * np.sin(B_infg * x + C_infg) / (x + 0.1) + D_infg

x_values = np.linspace(-5, 5, 400)

y_f = [fun_levenvergh(x) for x in x_values]
y_f1 = [fun_original(x) for x in x_values]
y_f2 = [fun_gauss(x) for x in x_values]

plt.figure(figsize=(10, 6))

plt.plot(x_values, y_f, label=f"x2 = ({A_inf:.4f} * sin({B_inf:.4f} * x1 + {C_inf:.4f})) / (x1 + 0.1) + {D_inf:.4f}", color='blue')
plt.plot(x_values, y_f1, label='$\\frac{\\sin{10x}}{10x}$', color='red')
plt.plot(x_values, y_f2, label=f"x2 = ({A_infg:.4f} * sin({B_infg:.4f} * x1 + {C_infg:.4f})) / (x1 + 0.1) + {D_infg:.4f}", color='orange', linestyle = 'dashed')

plt.title('Comparación de Modelos Ajustados vs Función Original')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

plt.xlim(0,5.1)
plt.ylim(-1,1.5)

plt.show()

# %%
#Calcular errores para el método de Levenberg-Marquardt

mselev = 0.0
msegauss = 0.0

for x1 in x1_inf_data:

    x2_real = fun_original(x1_inf_data)
    x2_pred_lev = fun_levenvergh(x1_inf_data)
    mselev += np.mean((x2_pred_lev - x2_real)**2)

    x2_pred_gauss = fun_gauss(x1_inf_data)
    msegauss += np.mean((x2_pred_gauss - x2_real)**2)

mselev /= len(x1_inf_data)
msegauss /= len(x1_inf_data)

print(f"Error Cuadrático Medio para Levenberg (MSE): {mselev:.10f}")

print(f"Error Cuadrático Medio para Gauss (MSE): {msegauss:.10f}")
# Out:
# Error Cuadrático Medio para Levenberg (MSE): 0.0094185092
# Error Cuadrático Medio para Gauss (MSE): 0.0094183050
# C:\Users\BEEPCOM\AppData\Local\Temp\ipykernel_23916\1014644096.py:8: RuntimeWarning: invalid value encountered in divide
#   np.sin(10 * x) / (10 * x)
